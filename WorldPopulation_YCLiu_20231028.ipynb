# %% [markdown]
# <a href="https://colab.research.google.com/github/halfmoonliu/CloudNB/blob/main/WorldPopulation_YCLiu_20231028.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Plotting World Population
# This JuPyter notebook demonstrates using Python's _pandas_ library's data preprocesisng and aggregation functionalities to obtain World Population by Region. Then, the _matplotplib_ library was used for plotting population distribution. The dataset is downloaded from [Kaggle](https://www.kaggle.com/datasets/sujaykapadnis/world-population-2023-countrywise).

# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Load Dataset
url = "https://raw.githubusercontent.com/halfmoonliu/CloudNB/main/WorldPopulation.csv"

# %%
Dataset = Dataset_raw[['Country, territory or other area ', 'Population', 'Region', 'ID']]
Dataset.dtypes
# Out:
# Country, territory or other area      object
# Population                           float64
# Region                                object
# ID                                     int64
# dtype: object

# %%
#Population by region
PopulationByRegion = Dataset.groupby('Region')['Population'].sum()
PopulationByRegion = PopulationByRegion.sort_values(ascending = False)
PopulationByRegion
# Out:
# Region
# East Asia               2324.0
# Central Asia            2044.7
# Africa                  1348.9
# Europe                   739.8
# Central & N. America     603.4
# Middle East              471.6
# S. America               440.1
# Oceania                   45.0
# Name: Population, dtype: float64

# %%
y_pos = np.arange(len(PopulationByRegion))
Label = ["East Asia", "Central Asia", "Africa", "Europe", "Central North America", "Middle East", "South America", "Oceania"]
plt.figure(figsize=(14,5))
plt.bar(y_pos, PopulationByRegion, align='center', alpha=0.5)
plt.xticks(y_pos, Label)
plt.ylabel('Population (M)',fontsize = 14)
plt.title('World Population by Region',fontsize = 24)

plt.show()
